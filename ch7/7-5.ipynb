# %% [markdown]
# # 깊은 다층 퍼셉트론으로 MNIST 손글씨 인식
# - 데이터 전처리, 모델 정의, 학습, 평가, 시각화 진행

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
ds.mnist
# Out:
# <module 'keras.datasets.mnist' from 'c:\\Users\\Inkyu_Yang\\anaconda3\\envs\\cv\\Lib\\site-packages\\keras\\datasets\\mnist\\__init__.py'>

# %% [markdown]
# ## 데이터 전처리
#
# - MNIST 데이터셋 불러오기 및 전처리
# - 데이터는 28x28 흑백 이미지를 1차원 벡터(784차원)로 변환
# - 픽셀 값을 [0, 1] 범위로 정규화
# - 레이블을 원-핫 인코딩으로 변환

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

# 데이터 정규화 및 1차원 벡터로 변환; 28x28 픽셀 이미지 60000장
# 다층 퍼셉트론은 1차원 벡터 입력을 필요로 함
x_train = x_train.reshape(60000, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(10000, 784).astype(np.float32) / 255.0

# 레이블을 원-핫 인코딩으로 변환, 10차원 벡터로 변환
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
dmlp = Sequential()
dmlp.add(Input(shape=(784,)))  # 1차원 벡터 입력층
dmlp.add(Dense(units=1024, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=10, activation='softmax'))  # 10개 클래스 출력층

# %% [markdown]
# ## 모델 컴파일 및 학습
#
# - 손실 함수: categorical_crossentropy (다중 클래스 분류)
# - 옵티마이저: Adam
# - 평가 지표: accuracy
# - 배치 크기 : 128, 에포크 : 50 으로 학습 진행

# %%
dmlp.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])
hist = dmlp.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 8s - 17ms/step - accuracy: 0.8398 - loss: 0.6119 - val_accuracy: 0.9306 - val_loss: 0.2731
# Epoch 2/30
# 469/469 - 6s - 14ms/step - accuracy: 0.8657 - loss: 0.5635 - val_accuracy: 0.9322 - val_loss: 0.2843
# Epoch 3/30
# 469/469 - 5s - 12ms/step - accuracy: 0.8677 - loss: 0.5711 - val_accuracy: 0.9329 - val_loss: 0.2644
# Epoch 4/30
# 469/469 - 6s - 14ms/step - accuracy: 0.8603 - loss: 0.6116 - val_accuracy: 0.9341 - val_loss: 0.2997
# Epoch 5/30
# 469/469 - 6s - 14ms/step - accuracy: 0.8638 - loss: 0.5929 - val_accuracy: 0.9391 - val_loss: 0.2698
# Epoch 6/30
# 469/469 - 6s - 13ms/step - accuracy: 0.8708 - loss: 0.5485 - val_accuracy: 0.9334 - val_loss: 0.3053
# Epoch 7/30
# 469/469 - 6s - 13ms/step - accuracy: 0.8599 - loss: 0.5882 - val_accuracy: 0.9323 - val_loss: 0.3358
# Epoch 8/30
# 469/469 - 6s - 12ms/step - accuracy: 0.8703 - loss: 0.5614 - val_accuracy: 0.9354 - val_loss: 0.3039
# Epoch 9/30
# 469/469 - 6s - 12ms/step - accuracy: 0.8620 - loss: 0.5714 - val_accuracy: 0.9329 - val_loss: 0.3724
# Epoch 10/30
# 469/469 - 6s - 13ms/step - accuracy: 0.8574 - loss: 0.6123 - val_accuracy: 0.9311 - val_loss: 0.3021
# Epoch 11/30
# 469/469 - 6s - 13ms/step - accuracy: 0.8607 - loss: 0.5977 - val_accuracy: 0.9364 - val_loss: 0.3382
# Epoch 12/30
# 469/469 - 15s - 31ms/step - accuracy: 0.8639 - loss: 0.5801 - val_accuracy: 0.9287 - val_loss: 0.3230
# Epoch 13/30
# 469/469 - 25s - 54ms/step - accuracy: 0.8579 - loss: 0.5904 - val_accuracy: 0.9327 - val_loss: 0.3587
# Epoch 14/30
# 469/469 - 13s - 28ms/step - accuracy: 0.8554 - loss: 0.6046 - val_accuracy: 0.9285 - val_loss: 0.3769
# Epoch 15/30
# 469/469 - 5s - 11ms/step - accuracy: 0.8528 - loss: 0.5884 - val_accuracy: 0.9253 - val_loss: 0.4177
# Epoch 16/30
# 469/469 - 5s - 11ms/step - accuracy: 0.8554 - loss: 0.6090 - val_accuracy: 0.9342 - val_loss: 0.4078
# Epoch 17/30
# 469/469 - 7s - 16ms/step - accuracy: 0.8608 - loss: 0.5905 - val_accuracy: 0.9280 - val_loss: 0.3735
# Epoch 18/30
# 469/469 - 23s - 48ms/step - accuracy: 0.8698 - loss: 0.5666 - val_accuracy: 0.9292 - val_loss: 0.3442
# Epoch 19/30
# 469/469 - 21s - 44ms/step - accuracy: 0.8624 - loss: 0.5960 - val_accuracy: 0.9263 - val_loss: 0.3548
# Epoch 20/30
# 469/469 - 21s - 44ms/step - accuracy: 0.8577 - loss: 0.6017 - val_accuracy: 0.9354 - val_loss: 0.4101
# Epoch 21/30
# 469/469 - 21s - 44ms/step - accuracy: 0.8655 - loss: 0.5686 - val_accuracy: 0.9268 - val_loss: 0.3264
# Epoch 22/30
# 469/469 - 20s - 43ms/step - accuracy: 0.8602 - loss: 0.5907 - val_accuracy: 0.9214 - val_loss: 0.4065
# Epoch 23/30
# 469/469 - 6s - 12ms/step - accuracy: 0.8557 - loss: 0.5969 - val_accuracy: 0.9310 - val_loss: 0.4386
# Epoch 24/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8578 - loss: 0.5765 - val_accuracy: 0.9271 - val_loss: 0.3922
# Epoch 25/30
# 469/469 - 5s - 10ms/step - accuracy: 0.8477 - loss: 0.5941 - val_accuracy: 0.9319 - val_loss: 0.3575
# Epoch 26/30
# 469/469 - 5s - 11ms/step - accuracy: 0.8603 - loss: 0.5536 - val_accuracy: 0.9315 - val_loss: 0.3874
# Epoch 27/30
# 469/469 - 5s - 12ms/step - accuracy: 0.8500 - loss: 0.5989 - val_accuracy: 0.9300 - val_loss: 0.4305
# Epoch 28/30
# 469/469 - 6s - 13ms/step - accuracy: 0.8597 - loss: 0.5480 - val_accuracy: 0.9249 - val_loss: 0.4002
# Epoch 29/30
# 469/469 - 9s - 18ms/step - accuracy: 0.8518 - loss: 0.6231 - val_accuracy: 0.9229 - val_loss: 0.4031
# Epoch 30/30
# 469/469 - 20s - 43ms/step - accuracy: 0.8527 - loss: 0.5861 - val_accuracy: 0.9356 - val_loss: 0.5126

# %% [markdown]
# ## 모델 평가

# %%
accuracy = dmlp.evaluate(x_test, y_test, verbose=0)[1] * 100  # 손실값과 정확도 중 정확도 백분율 추출
print(f'정확률 = {accuracy:.2f}%')
# Out:
# 정확률 = 93.56%

# %% [markdown]
# ## 모델 저장

# %%
dmlp.save('dmlp_trained.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 모델 시각화

# %%
# 정확도 그래프
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# 손실 그래프
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

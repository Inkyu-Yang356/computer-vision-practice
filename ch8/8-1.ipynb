# %% [markdown]
# # 예제 1 : 우편번호 인식기 v2
# - 1.1. LeNet 재현
# - 1.2. 우편번호 인식기 v2 구현

# %% [markdown]
# ## 1.1 : LeNet 재현

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dropout,Dense,Input
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### 데이터 준비

# %%
(x_train,y_train),(x_test,y_test)=ds.mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Conversion to gray-scale images
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
# Normalization
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0

# %%
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# %% [markdown]
# ### 모델 정의

# %%
cnn=Sequential()
input = Input(shape=(28,28,1))
cnn.add(input)
cnn.add(Conv2D(6,(5,5),padding='same',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(16,(5,5),padding='valid',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2),strides=2))
cnn.add(Conv2D(120,(5,5),padding='valid',activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(units=84,activation='relu'))
cnn.add(Dense(units=10,activation='softmax'))

# %% [markdown]
# ### 학습 및 평가

# %%
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
cnn.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 7s - 14ms/step - accuracy: 0.9172 - loss: 0.2843 - val_accuracy: 0.9707 - val_loss: 0.0929
# Epoch 2/30
# 469/469 - 4s - 9ms/step - accuracy: 0.9767 - loss: 0.0772 - val_accuracy: 0.9850 - val_loss: 0.0491
# Epoch 3/30
# 469/469 - 4s - 8ms/step - accuracy: 0.9829 - loss: 0.0555 - val_accuracy: 0.9852 - val_loss: 0.0452
# Epoch 4/30
# 469/469 - 11s - 23ms/step - accuracy: 0.9868 - loss: 0.0431 - val_accuracy: 0.9888 - val_loss: 0.0346
# Epoch 5/30
# 469/469 - 22s - 47ms/step - accuracy: 0.9887 - loss: 0.0355 - val_accuracy: 0.9884 - val_loss: 0.0349
# Epoch 6/30
# 469/469 - 15s - 33ms/step - accuracy: 0.9898 - loss: 0.0307 - val_accuracy: 0.9880 - val_loss: 0.0359
# Epoch 7/30
# 469/469 - 21s - 44ms/step - accuracy: 0.9916 - loss: 0.0264 - val_accuracy: 0.9875 - val_loss: 0.0363
# Epoch 8/30
# 469/469 - 21s - 44ms/step - accuracy: 0.9929 - loss: 0.0223 - val_accuracy: 0.9904 - val_loss: 0.0316
# Epoch 9/30
# 469/469 - 20s - 43ms/step - accuracy: 0.9943 - loss: 0.0181 - val_accuracy: 0.9905 - val_loss: 0.0314
# Epoch 10/30
# 469/469 - 20s - 43ms/step - accuracy: 0.9943 - loss: 0.0173 - val_accuracy: 0.9885 - val_loss: 0.0367
# Epoch 11/30
# 469/469 - 22s - 47ms/step - accuracy: 0.9954 - loss: 0.0143 - val_accuracy: 0.9882 - val_loss: 0.0403
# Epoch 12/30
# 469/469 - 18s - 38ms/step - accuracy: 0.9959 - loss: 0.0129 - val_accuracy: 0.9898 - val_loss: 0.0389
# Epoch 13/30
# 469/469 - 18s - 39ms/step - accuracy: 0.9961 - loss: 0.0119 - val_accuracy: 0.9887 - val_loss: 0.0441
# Epoch 14/30
# 469/469 - 23s - 50ms/step - accuracy: 0.9960 - loss: 0.0115 - val_accuracy: 0.9908 - val_loss: 0.0371
# Epoch 15/30
# 469/469 - 32s - 69ms/step - accuracy: 0.9969 - loss: 0.0102 - val_accuracy: 0.9894 - val_loss: 0.0402
# Epoch 16/30
# 469/469 - 22s - 48ms/step - accuracy: 0.9969 - loss: 0.0085 - val_accuracy: 0.9881 - val_loss: 0.0424
# Epoch 17/30
# 469/469 - 17s - 36ms/step - accuracy: 0.9972 - loss: 0.0081 - val_accuracy: 0.9902 - val_loss: 0.0418
# Epoch 18/30
# 469/469 - 16s - 35ms/step - accuracy: 0.9973 - loss: 0.0084 - val_accuracy: 0.9900 - val_loss: 0.0359
# Epoch 19/30
# 469/469 - 17s - 37ms/step - accuracy: 0.9974 - loss: 0.0077 - val_accuracy: 0.9884 - val_loss: 0.0448
# Epoch 20/30
# 469/469 - 19s - 41ms/step - accuracy: 0.9975 - loss: 0.0073 - val_accuracy: 0.9890 - val_loss: 0.0421
# Epoch 21/30
# 469/469 - 18s - 38ms/step - accuracy: 0.9986 - loss: 0.0039 - val_accuracy: 0.9897 - val_loss: 0.0424
# Epoch 22/30
# 469/469 - 17s - 36ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9890 - val_loss: 0.0445
# Epoch 23/30
# 469/469 - 20s - 42ms/step - accuracy: 0.9977 - loss: 0.0063 - val_accuracy: 0.9890 - val_loss: 0.0460
# Epoch 24/30
# 469/469 - 18s - 37ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9924 - val_loss: 0.0373
# Epoch 25/30
# 469/469 - 15s - 32ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.9903 - val_loss: 0.0483
# Epoch 26/30
# 469/469 - 21s - 45ms/step - accuracy: 0.9980 - loss: 0.0064 - val_accuracy: 0.9892 - val_loss: 0.0492
# Epoch 27/30
# 469/469 - 12s - 27ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9910 - val_loss: 0.0451
# Epoch 28/30
# 469/469 - 5s - 12ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9915 - val_loss: 0.0430
# Epoch 29/30
# 469/469 - 5s - 11ms/step - accuracy: 0.9979 - loss: 0.0063 - val_accuracy: 0.9905 - val_loss: 0.0464
# Epoch 30/30
# 469/469 - 4s - 9ms/step - accuracy: 0.9983 - loss: 0.0046 - val_accuracy: 0.9903 - val_loss: 0.0543

# %%
res=cnn.evaluate(x_test,y_test,verbose=0)
print('정확도=',res[1]*100)
# Out:
# 정확도= 99.02999997138977

# %% [markdown]
# ### 모델 저장

# %%
cnn.save('cnn_v2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 1.2. : 우편번호 인식기 v2 구현

# %% [markdown]
# ### 라이브러리 불러오기

# %%
## 라이브러리 불러오기
import numpy as np
import tensorflow as tf
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ### 저장한 모델 불러오기
#
# - `LeNet` 재현 실습을 통해 저장한 모델 불러오기
# - MNIST 데이터셋으로 학습된 손글씨 숫자 인식 모델

# %%
model = tf.keras.models.load_model('cnn_v2.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### 초기화 함수 정의
# - 우편번호 작성 화면 초기화
# - 5개의 숫자를 작성할 수 있는 영역 생성, 안내 텍스트 표시

# %%
def reset():
    global img
    img = np.ones((200, 520, 3), dtype=np.uint8) * 255
    for i in range(5):
        cv.rectangle(img, (10 + i * 100, 50), (10 + (i + 1) * 100, 150), (0, 0, 255))
    cv.putText(img, 'e:erase s:show r:recognition q:quit', (10, 40), cv.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 1)

# %% [markdown]
# ### 숫자 추출 함수 정의
# - 작성된 숫자를 추출하여 모델이 처리할 수 있는 형태로 변환
# - 각 숫자는 28x28 크기로 리사이즈, 흑백으로 변환

# %%
def grab_numerals():
    numerals = []
    for i in range(5):
        roi = img[51:149, 11 + i * 100:9 + (i + 1) * 100, 0]
        roi = 255 - cv.resize(roi, (28, 28), interpolation=cv.INTER_CUBIC)
        numerals.append(roi)
    numerals = np.array(numerals)
    return numerals

# %% [markdown]
# ### 숫자 시각화 함수 정의
#
# - 추출된 숫자를 화면에 표시
# - 사용자가 작성한 숫자 확인 가능

# %%
def show():
    numerals = grab_numerals()
    plt.figure(figsize=(25, 5))
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(numerals[i], cmap='gray')
        plt.xticks([]); plt.yticks([])
    plt.show()

# %% [markdown]
# ### 숫자 인식 함수 정의
# - 추출된 숫자를 모델에 입력하여 예측
# - 예측된 숫자는 화면에 표시되고 소리를 재생함

# %%
def recognition():
    numerals = grab_numerals()
    numerals = numerals.reshape(5, 28, 28) # 지난 실습 7-7.ipynb (5, 784)에서 (5, 28, 28) 로 변경
    numerals = numerals.astype(np.float32) / 255.0
    res = model.predict(numerals)  # 신경망 모델로 예측
    class_id = np.argmax(res, axis=1)
    for i in range(5):
        cv.putText(img, str(class_id[i]), (50 + i * 100, 180), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 1)
    # winsound.Beep(1000, 500)

# %% [markdown]
# ### 마우스 이벤트 처리
#
# - 왼쪽 버튼을 클릭하거나 드래그하면 숫자를 작성할 수 있음

# %%
BrushSiz = 4
LColor = (0, 0, 0)

def writing(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        cv.circle(img, (x, y), BrushSiz, LColor, -1)
    elif event == cv.EVENT_MOUSEMOVE and flags == cv.EVENT_FLAG_LBUTTON:
        cv.circle(img, (x, y), BrushSiz, LColor, -1)

# %% [markdown]
# ### 메인 루프
#
# - 사용자는 'e', 's', 'r', 'q' 키를 사용하여 초기화, 시각화, 인식, 종료를 수행함

# %%
reset()
cv.namedWindow('Writing')
cv.setMouseCallback('Writing', writing)

while True:
    cv.imshow('Writing', img)
    key = cv.waitKey(1)
    if key == ord('e'):
        reset()
    elif key == ord('s'):
        show()
    elif key == ord('r'):
        recognition()
    elif key == ord('q'):
        break

cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
